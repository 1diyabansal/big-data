# %% [markdown]
# <a href="https://colab.research.google.com/github/1diyabansal/big-data/blob/main/lab_eval_mca3_202301073.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 ques


import pandas as pd
import matplotlib.pyplot as plt
import io
import seaborn as sns

data=pd.read_csv("/content/company_sales_data.csv")
data
plt.bar(data["month_number"],data["facecream"],label="facecream",color='green')

plt.xlabel('month')
plt.ylabel('sales')
plt.title("Bar chart")
plt.legend()
plt.show()

# %%
plt.bar(data["month_number"],data["facewash"],label="facewash")
plt.xlabel('month')
plt.ylabel('sales')
plt.title("Bar chart")
plt.legend()
plt.show()

# %%
#2 ques


monthList= data['month_number'].tolist()
faceCremSalesData=data['facecream'].tolist()
faceWashSalesData=data['facewash'].tolist()

plt.hist(total_profit_by_month)
plt.title('Total Profit by Month')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')

plt.show()
